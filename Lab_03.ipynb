# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51027/ADM_Lab/blob/main/Lab_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = np.random.randn(1000)
sns.histplot(data, bins=30, kde=True)
plt.title("Histogram Plot")
plt.show()

# %%
df = pd.DataFrame({"x" : np.random.rand(100), "y" : np.random.rand(100)})
sns.scatterplot(data=df, x="x", y="y")
plt.title("Scatter Plot Example")
plt.show()

# %%
import matplotlib.pyplot as pl
import numpy as np
x = np.linspace(-np.pi, np.pi, 256, endpoint = True)
y = np.cos(x)
y1 = np.sin(x)
pl.plot(x, y)
pl.plot(x, y1)
pl.show()

# %%
import pandas as ps
import numpy as np

data = {
    "Age" : np.random.randint(18, 65, 200),
    "Purchase_Amount" : np.random.normal(100, 50, 200).clip(10, 300),
    "Category" : np.random.choice(["Electronics", "Clothing", "Books"], 200)
}

df = pd.DataFrame(data)
df.head()
#print(df)
# Out:
#    Age  Purchase_Amount     Category
# 0   63       140.572293  Electronics
# 1   20        72.122277     Clothing
# 2   56        33.569096  Electronics
# 3   21        58.271883        Books
# 4   48        89.001623  Electronics
