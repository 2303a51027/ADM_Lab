# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51027/ADM_Lab/blob/main/Lab_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xp = np.array([0, 3, 6])
yp = np.array([0, 100, 250])

plt.plot(xp, yp, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xp = np.array([0, 6])
yp = np.array([250, 10])

plt.plot(xp, yp)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xp = np.array([1, 4, 6, 9])
yp = np.array([1, 40, 1, 90])

plt.plot(xp, yp)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

yp = np.array([3, 8, 1, 10, 5, 7])

plt.plot(yp)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xp = np.array([0, 70, 70, 0, 0, 70, 70, 0, 35])
yp = np.array([10, 10, 70, 70, 10, 70, 10, 70, 40])

plt.plot(xp, yp, 'o--', color = 'purple')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#xp = np.array([0, 70, 70, 0, 0, 70, 70, 0, 35])
yp = np.array([10, 10, 70, 70, 10, 70, 10, 70, 40])

plt.plot(yp, marker = 'o', ms = 20, mec = 'red', mfc = 'blue', ls = ':', color = 'r', linewidth = 20.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
y = np.array([12000, 14500, 15200, 13800, 16400, 18000, 19500, 17900, 16800, 20100, 22500, 25000])

plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.array(["Jan", "Feb", "Mar", "Apr"])
b = np.array([35, 33, 30, 28])
c = np.array([30, 32, 35, 37])
d = np.array([20, 22, 25, 27])
e = np.array([15, 13, 10, 8])

mylabels = ["Jan", "Feb", "Mar", "Apr"]
plt.pie(b, labels = mylabels)
# plt.pie(c, label = a,)
# plt.pie(d, label = a)
# plt.pie(e, label = a)
plt.show()

#plt.grid()
#plt.grid(axis = 'x')
#plt.grid(axis = 'y')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()
